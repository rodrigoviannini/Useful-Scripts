# %% [markdown]
# ## Install

# %%
# !pip install geopy;
# !pip install pycep-correios;
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 100 kB 3.6 MB/s
# ...
#      |████████████████████████████████| 6.4 MB 26.7 MB/s
# ...
#      |████████████████████████████████| 41 kB 470 kB/s
# ...
#      |████████████████████████████████| 54 kB 2.9 MB/s
# ...
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# ...

# %% [markdown]
# ## Imports

# %%
from geopy.geocoders import Nominatim
import pycep_correios

# %% [markdown]
# ## Functions

# %% [markdown]
# **INPUT:** endereço
#
#
# **OUTPUT:** latitude/ longitude

# %%
def extrai_lat_long_endereco(endereco):
    geolocator = Nominatim(user_agent="geolocalização")
    location = geolocator.geocode(endereco)


    return (location.latitude, location.longitude)

# %%
extrai_lat_long_endereco('Rua Vicente Geronasso')
# Out:
# (-25.3842409, -49.2534777)

# %% [markdown]
# **INPUT:** cep
#
#
# **OUTPUT:** latitude/ longitude

# %%
def extrai_lat_long_cep(cep):
    endereco = pycep_correios.get_address_from_cep(cep)

    geolocator = Nominatim(user_agent="test_app")
    location = geolocator.geocode(endereco['logradouro'] + ", " + endereco['cidade'] + " - " + endereco['bairro'])

    return(location.latitude, location.longitude)

# %%
extrai_lat_long_cep('82560-500')
# Out:
# (-25.3845741, -49.236354)

# %% [markdown]
# **INPUT:** cep
#
#
# **OUTPUT:** baiiro/ cep/ cidade / complemento/ lougradouro/ uf

# %%
import pycep_correios

def extrai_endereco_cep(cep):
    endereco = pycep_correios.get_address_from_cep(cep)
    return endereco

# %%
extrai_endereco_cep('82560-100')
# Out:
# {'bairro': 'Barreirinha',
#  'cep': '82560-100',
#  'cidade': 'Curitiba',
#  'complemento': '',
#  'logradouro': 'Rua União da Vitória',
#  'uf': 'PR'}

# %% [markdown]
# ## MAPS

# %% [markdown]
# **EM FASE DE TESTES**

# %%
import pandas as pd
df = pd.read_excel('/content/EXEMPLO_ENDERECOS_5.xlsx')
df.head()
# Out:
#       APARELHO       BAIRRO     CIDADE  UF   LATITUDE  LONGITUDE        CEP  \
# 0      CDOE_M1    Boa Vista  São Paulo  SP -253845741  -49236354  82560-500
# 1      CDOE_M3    Boa Vista  São Paulo  SP -253842409 -492534777  82560-270
# 2  POWER_METER    Boa Vista  São Paulo  SP -253822971 -492488275  82560-300
# 3   PINGADEIRA  Barreirinha  São Paulo  SP -253810879 -492603463  82560-100
#
#    RAIO
# 0    10
# 1    10
# 2    10
# 3    10

# %%
import plotly.express as px
import plotly.figure_factory as ff

# %%
fig = px.density_mapbox(df, lat='LATITUDE', lon='LONGITUDE', radius=1, zoom=10, 
mapbox_style="stamen-terrain", hover_name= 'APARELHO', z='RAIO')

fig.update_layout(title = 'MAPA DE LOCALIZAÇÕES')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
